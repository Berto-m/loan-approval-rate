# %%
# %tensorflow_version 2.x
import tensorflow as tf
tf.__version__
# Out:
# '2.2.0'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-338a6496-d76d-4221-8695-2ff1d50d66b1" name="files[]" multiple disabled />
#      <output id="result-338a6496-d76d-4221-8695-2ff1d50d66b1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lending_club_info.csv to lending_club_info.csv

# %%
dfg = pd.read_csv('lending_club_info.csv')

# %%
dfg.set_index('LoanStatNew', inplace=True)

# %%
dfg.head()
# Out:
#                                                    Description
# LoanStatNew
# loan_amnt    The listed amount of the loan applied for by t...
# term         The number of payments on the loan. Values are...
# int_rate                             Interest Rate on the loan
# installment  The monthly payment owed by the borrower if th...
# grade                                   LC assigned loan grade

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d8cb9004-c631-4cd8-ba8e-73cc3e62c14e" name="files[]" multiple disabled />
#      <output id="result-d8cb9004-c631-4cd8-ba8e-73cc3e62c14e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lending_club_loan_two.csv to lending_club_loan_two.csv

# %%
def feat_info(col_name):
    print(dfg.loc[col_name]['Description'])

# %%
df = pd.read_csv('lending_club_loan_two.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             396030 non-null  float64
#  1   term                  396030 non-null  object
#  2   int_rate              396030 non-null  float64
#  3   installment           396030 non-null  float64
#  4   grade                 396030 non-null  object
#  5   sub_grade             396030 non-null  object
#  6   emp_title             373103 non-null  object
#  7   emp_length            377729 non-null  object
#  8   home_ownership        396030 non-null  object
#  9   annual_inc            396030 non-null  float64
#  10  verification_status   396030 non-null  object
#  11  issue_d               396030 non-null  object
#  12  loan_status           396030 non-null  object
#  13  purpose               396030 non-null  object
# ...

# %%
df.head()
# Out:
#    loan_amnt  ...                                            address
# 0    10000.0  ...     0174 Michelle Gateway\r\nMendozaberg, OK 22690
# 1     8000.0  ...  1076 Carney Fort Apt. 347\r\nLoganmouth, SD 05113
# 2    15600.0  ...  87025 Mark Dale Apt. 269\r\nNew Sabrina, WV 05113
# 3     7200.0  ...            823 Reid Ford\r\nDelacruzside, MA 00813
# 4    24375.0  ...             679 Luna Roads\r\nGreggshire, VA 11650
#
# [5 rows x 27 columns]

# %%
feat_info('grade')
# Out:
# LC assigned loan grade

# %%
df.describe()
# Out:
#            loan_amnt       int_rate  ...       mort_acc  pub_rec_bankruptcies
# count  396030.000000  396030.000000  ...  358235.000000         395495.000000
# mean    14113.888089      13.639400  ...       1.813991              0.121648
# std      8357.441341       4.472157  ...       2.147930              0.356174
# min       500.000000       5.320000  ...       0.000000              0.000000
# 25%      8000.000000      10.490000  ...       0.000000              0.000000
# 50%     12000.000000      13.330000  ...       1.000000              0.000000
# 75%     20000.000000      16.490000  ...       3.000000              0.000000
# max     40000.000000      30.990000  ...      34.000000              8.000000
#
# [8 rows x 12 columns]

# %%
sns.countplot(data=df, x='loan_status')

# %%
sns.distplot(df.loan_amnt, bins=30)

# %%
df.corr()
# Out:
#                       loan_amnt  int_rate  ...  mort_acc  pub_rec_bankruptcies
# loan_amnt              1.000000  0.168921  ...  0.222315             -0.106539
# int_rate               0.168921  1.000000  ... -0.082583              0.057450
# installment            0.953929  0.162758  ...  0.193694             -0.098628
# annual_inc             0.336887 -0.056771  ...  0.236320             -0.050162
# dti                    0.016636  0.079038  ... -0.025439             -0.014558
# open_acc               0.198556  0.011649  ...  0.109205             -0.027732
# pub_rec               -0.077779  0.060986  ...  0.011552              0.699408
# revol_bal              0.328320 -0.011280  ...  0.194925             -0.124532
# revol_util             0.099911  0.293659  ...  0.007514             -0.086751
# total_acc              0.223886 -0.036404  ...  0.381072              0.042035
# mort_acc               0.222315 -0.082583  ...  1.000000              0.027239
# ...

# %%
feat_info('installment')
# Out:
# The monthly payment owed by the borrower if the loan originates.

# %%
df['installment'].describe()
# Out:
# count    396030.000000
# mean        431.849698
# std         250.727790
# min          16.080000
# 25%         250.330000
# 50%         375.430000
# 75%         567.300000
# max        1533.810000
# Name: installment, dtype: float64

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x=df.loan_amnt, y=df.installment)

# %%
plt.figure(figsize=(12,7))
sns.heatmap(df.corr(),annot=True,cmap='viridis')

# %%
df[df.installment	 > 0].sort_values(by=['installment'], ascending=False).head(3)
# Out:
#         loan_amnt  ...                                            address
# 6093      38225.0  ...     39219 Andrew Canyon\r\nGallowayshire, OK 30723
# 26653     40000.0  ...  9398 Tina Valley Apt. 412\r\nPort Lorettachest...
# 297246    38275.0  ...                 PSC 9113, Box 5711\r\nAPO AP 70466
#
# [3 rows x 27 columns]

# %%
df[df.loan_amnt	 > 0].sort_values(by=['loan_amnt'], ascending=False).head(3)
# Out:
#         loan_amnt  ...                                         address
# 211032    40000.0  ...  4818 Amy Track Apt. 580\r\nJonesberg, AL 48052
# 109976    40000.0  ...      780 John Glens\r\nSouth Victoria, MI 05113
# 32446     40000.0  ...      32186 Jason Rue\r\nSherrychester, CO 30723
#
# [3 rows x 27 columns]

# %% [markdown]
# ### **Categories to consider/change**
#
#
# ```
# # make it nuemric and cetogical
# >>> df.emp_length.value_counts()
# ```
#
#
# ```
# # Think about this
# # It ia the month in which the loan was funded
# >>> df.issue_d.value_counts()
# ```
# Drop the title col, way to many categeries for the AI

# %%
sns.boxplot(data=df, x='loan_status', y='loan_amnt')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             396030 non-null  float64
#  1   term                  396030 non-null  object
#  2   int_rate              396030 non-null  float64
#  3   installment           396030 non-null  float64
#  4   grade                 396030 non-null  object
#  5   sub_grade             396030 non-null  object
#  6   emp_title             373103 non-null  object
#  7   emp_length            377729 non-null  object
#  8   home_ownership        396030 non-null  object
#  9   annual_inc            396030 non-null  float64
#  10  verification_status   396030 non-null  object
#  11  issue_d               396030 non-null  object
#  12  loan_status           396030 non-null  object
#  13  purpose               396030 non-null  object
# ...

# %%
df.groupby('loan_status')['loan_amnt'].describe()
# Out:
#                 count          mean          std  ...      50%      75%      max
# loan_status                                       ...
# Charged Off   77673.0  15126.300967  8505.090557  ...  14000.0  20000.0  40000.0
# Fully Paid   318357.0  13866.878771  8302.319699  ...  12000.0  19225.0  40000.0
#
# [2 rows x 8 columns]

# %%
sorted(df.grade.unique())
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
sorted(df.sub_grade.unique())
# Out:
# ['A1',
#  'A2',
#  'A3',
#  'A4',
#  'A5',
#  'B1',
#  'B2',
#  'B3',
#  'B4',
#  'B5',
#  'C1',
#  'C2',
#  'C3',
#  'C4',
#  'C5',
#  'D1',
#  'D2',
#  'D3',
#  'D4',
#  'D5',
#  'E1',
#  'E2',
#  'E3',
#  'E4',
#  'E5',
#  'F1',
#  'F2',
#  'F3',
#  'F4',
#  'F5',
#  'G1',
#  'G2',
#  'G3',
#  'G4',
#  'G5']

# %%
sns.countplot(data=df, x='grade', hue='loan_status')

# %% [markdown]
# ### **How to order a count plot or any sort of plot**
#
# To sort a categorical data/strings, we can use the **unique()** method, this method however, returns an array. Thefore the **sort_values() WON'T WORK**.
#
# Sort array:
#
#
# ```
# >>> sorted(df.sub_grade.unique())
# ['A1', 'A2', 'A3', 'A4', 'A5', 'B1', 'B2',...]
# ```
#
# we can then save the sorted method to a variable and use it in the order paramater for the seaborn **countplot()** method as shown below
#
#
# ```
# >>> sorted_sub_grade =  sorted(df.sub_grade.unique())
# >>> sns.countplot(data=df, x='sub_grade', order=sorted_sub_grade, palette='coolwarm')
#
# OR
#
# # Llttle messy
# >>> sns.countplot(data=df, x='sub_grade', order=sorted(df.sub_grade.unique()), palette='coolwarm')
# ```

# %%
plt.figure(figsize=(15,5))
sorted_sub_grade =  sorted(df.sub_grade.unique())
sns.countplot(data=df, x='sub_grade', order=sorted_sub_grade, palette='coolwarm')

# %%
plt.figure(figsize=(15,5))
sorted_sub_grade =  sorted(df.sub_grade.unique())
sns.countplot(data=df, x='sub_grade', order=sorted_sub_grade, palette='coolwarm',hue='loan_status')

# %%
f_and_g = df[(df['grade']=='G') | (df['grade']=='F')]

plt.figure(figsize=(12,4))
subgrade_order = sorted(f_and_g['sub_grade'].unique())
sns.countplot(x='sub_grade',data=f_and_g,order = subgrade_order,hue='loan_status')

# %% [markdown]
# ## **How to map**

# %%
df['loan_repaid'] = df['loan_status'].map({'Fully Paid':1,'Charged Off':0})
df[['loan_repaid','loan_status']]
# Out:
#         loan_repaid  loan_status
# 0                 1   Fully Paid
# 1                 1   Fully Paid
# 2                 1   Fully Paid
# 3                 1   Fully Paid
# 4                 0  Charged Off
# ...             ...          ...
# 396025            1   Fully Paid
# 396026            1   Fully Paid
# 396027            1   Fully Paid
# 396028            1   Fully Paid
# 396029            1   Fully Paid
#
# [396030 rows x 2 columns]

# %%
df.corr()['loan_repaid']
# to be reviewed
# Out:
# loan_amnt              -0.059836
# int_rate               -0.247758
# installment            -0.041082
# annual_inc              0.053432
# dti                    -0.062413
# open_acc               -0.028012
# pub_rec                -0.019933
# revol_bal               0.010892
# revol_util             -0.082373
# total_acc               0.017893
# mort_acc                0.073111
# pub_rec_bankruptcies   -0.009383
# loan_repaid             1.000000
# Name: loan_repaid, dtype: float64

# %% [markdown]
# ## **Missing values**

# %%
len(df)
# Out:
# 396030

# %%
df.isnull().sum()
# Out:
# loan_amnt                   0
# term                        0
# int_rate                    0
# installment                 0
# grade                       0
# sub_grade                   0
# emp_title               22927
# emp_length              18301
# home_ownership              0
# annual_inc                  0
# verification_status         0
# issue_d                     0
# loan_status                 0
# purpose                     0
# title                    1755
# dti                         0
# earliest_cr_line            0
# open_acc                    0
# pub_rec                     0
# revol_bal                   0
# revol_util                276
# total_acc                   0
# initial_list_status         0
# application_type            0
# mort_acc                37795
# pub_rec_bankruptcies      535
# address                     0
# loan_repaid                 0
# dtype: int64

# %%
100 * df.isnull().sum() / len(df)
# Out:
# loan_amnt               0.000000
# term                    0.000000
# int_rate                0.000000
# installment             0.000000
# grade                   0.000000
# sub_grade               0.000000
# emp_title               5.789208
# emp_length              4.621115
# home_ownership          0.000000
# annual_inc              0.000000
# verification_status     0.000000
# issue_d                 0.000000
# loan_status             0.000000
# purpose                 0.000000
# title                   0.443148
# dti                     0.000000
# earliest_cr_line        0.000000
# open_acc                0.000000
# pub_rec                 0.000000
# revol_bal               0.000000
# revol_util              0.069692
# total_acc               0.000000
# initial_list_status     0.000000
# application_type        0.000000
# mort_acc                9.543469
# pub_rec_bankruptcies    0.135091
# address                 0.000000
# loan_repaid             0.000000
# dtype: float64

# %%
df.emp_title.nunique()
# Out:
# 173105

# %%
df.emp_title.value_counts()
# Out:
# Teacher                             4389
# Manager                             4250
# Registered Nurse                    1856
# RN                                  1846
# Supervisor                          1830
#                                     ...
# medical eqiupment                      1
# OP ADMIN                               1
# M&I Bank                               1
# IT Systems Security Associate II       1
# Rack Express/Ace Forklift              1
# Name: emp_title, Length: 173105, dtype: int64

# %%
df = df.drop('emp_title',axis=1)

# %%
#This still ordered
sorted(df.emp_length.dropna().unique())
# Out:
# ['1 year',
#  '10+ years',
#  '2 years',
#  '3 years',
#  '4 years',
#  '5 years',
#  '6 years',
#  '7 years',
#  '8 years',
#  '9 years',
#  '< 1 year']

# %%
# we can manually copy it and paste it
emp_length_order = [
'< 1 year',
  '1 year',
  '2 years',
  '3 years',
  '4 years',
  '5 years',
  '6 years',
  '7 years',
  '8 years',
  '9 years',
  '10+ years'
 ]

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='emp_length',data=df,order=emp_length_order)

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='emp_length',data=df,order=emp_length_order, hue='loan_status')

# %%
emp_co = df[df['loan_status']=='Charged Off'].groupby('emp_length').count()['loan_status']

# %%
emp_fp = df[df['loan_status']=='Fully Paid'].groupby('emp_length').count()['loan_status']

# %% [markdown]
# This basically tells that there ins't much information about or correlation.

# %%
# percent of didn't pay back verson the people who did
emp_co/emp_fp
# Out:
# emp_length
# 1 year       0.248649
# 10+ years    0.225770
# 2 years      0.239560
# 3 years      0.242593
# 4 years      0.238213
# 5 years      0.237911
# 6 years      0.233341
# 7 years      0.241887
# 8 years      0.249625
# 9 years      0.250735
# < 1 year     0.260830
# Name: loan_status, dtype: float64

# %%
# drop emp-length 
df = df.drop('emp_length', axis=1)

# %%
df.isnull().sum()
# Out:
# loan_amnt                   0
# term                        0
# int_rate                    0
# installment                 0
# grade                       0
# sub_grade                   0
# home_ownership              0
# annual_inc                  0
# verification_status         0
# issue_d                     0
# loan_status                 0
# purpose                     0
# title                    1755
# dti                         0
# earliest_cr_line            0
# open_acc                    0
# pub_rec                     0
# revol_bal                   0
# revol_util                276
# total_acc                   0
# initial_list_status         0
# application_type            0
# mort_acc                37795
# pub_rec_bankruptcies      535
# address                     0
# loan_repaid                 0
# dtype: int64

# %%
df.title.head(10)
# Out:
# 0                   Vacation
# 1         Debt consolidation
# 2    Credit card refinancing
# 3    Credit card refinancing
# 4      Credit Card Refinance
# 5         Debt consolidation
# 6           Home improvement
# 7       No More Credit Cards
# 8         Debt consolidation
# 9         Debt Consolidation
# Name: title, dtype: object

# %%
df.purpose.head(10)
# Out:
# 0              vacation
# 1    debt_consolidation
# 2           credit_card
# 3           credit_card
# 4           credit_card
# 5    debt_consolidation
# 6      home_improvement
# 7           credit_card
# 8    debt_consolidation
# 9    debt_consolidation
# Name: purpose, dtype: object

# %%
feat_info('purpose')
# Out:
# A category provided by the borrower for the loan request.

# %%
df = df.drop('title', axis=1)

# %%
feat_info('mort_acc')
# Out:
# Number of mortgage accounts.

# %%
df.mort_acc.value_counts()
# Out:
# 0.0     139777
# 1.0      60416
# 2.0      49948
# 3.0      38049
# 4.0      27887
# 5.0      18194
# 6.0      11069
# 7.0       6052
# 8.0       3121
# 9.0       1656
# 10.0       865
# 11.0       479
# 12.0       264
# 13.0       146
# 14.0       107
# 15.0        61
# 16.0        37
# 17.0        22
# 18.0        18
# 19.0        15
# 20.0        13
# 24.0        10
# 22.0         7
# 21.0         4
# 25.0         4
# 27.0         3
# 23.0         2
# 32.0         2
# 26.0         2
# 31.0         2
# 30.0         1
# 28.0         1
# 34.0         1
# Name: mort_acc, dtype: int64

# %%
df.corr().mort_acc.sort_values()
# Out:
# int_rate               -0.082583
# dti                    -0.025439
# revol_util              0.007514
# pub_rec                 0.011552
# pub_rec_bankruptcies    0.027239
# loan_repaid             0.073111
# open_acc                0.109205
# installment             0.193694
# revol_bal               0.194925
# loan_amnt               0.222315
# annual_inc              0.236320
# total_acc               0.381072
# mort_acc                1.000000
# Name: mort_acc, dtype: float64

# %%
total_acc_avg = df.groupby('total_acc').mean().mort_acc
total_acc_avg
# Out:
# total_acc
# 2.0      0.000000
# 3.0      0.052023
# 4.0      0.066743
# 5.0      0.103289
# 6.0      0.151293
#            ...
# 124.0    1.000000
# 129.0    1.000000
# 135.0    3.000000
# 150.0    2.000000
# 151.0    0.000000
# Name: mort_acc, Length: 118, dtype: float64

# %%
def fill_mort_acc(total_acc,mort_acc):
  
  if np.isnan(mort_acc):
    return total_acc_avg[total_acc]
  else:
    return mort_acc

# %%
df['mort_acc'] = df.apply(lambda x: fill_mort_acc(x['total_acc'], x['mort_acc']), axis=1)

# %%
df.isnull().sum()
# Out:
# loan_amnt                 0
# term                      0
# int_rate                  0
# installment               0
# grade                     0
# sub_grade                 0
# home_ownership            0
# annual_inc                0
# verification_status       0
# issue_d                   0
# loan_status               0
# purpose                   0
# dti                       0
# earliest_cr_line          0
# open_acc                  0
# pub_rec                   0
# revol_bal                 0
# revol_util              276
# total_acc                 0
# initial_list_status       0
# application_type          0
# mort_acc                  0
# pub_rec_bankruptcies    535
# address                   0
# loan_repaid               0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# loan_amnt               0
# term                    0
# int_rate                0
# installment             0
# grade                   0
# sub_grade               0
# home_ownership          0
# annual_inc              0
# verification_status     0
# issue_d                 0
# loan_status             0
# purpose                 0
# dti                     0
# earliest_cr_line        0
# open_acc                0
# pub_rec                 0
# revol_bal               0
# revol_util              0
# total_acc               0
# initial_list_status     0
# application_type        0
# mort_acc                0
# pub_rec_bankruptcies    0
# address                 0
# loan_repaid             0
# dtype: int64

# %%
df.select_dtypes(['object']).columns
# Out:
# Index(['term', 'grade', 'sub_grade', 'home_ownership', 'verification_status',
#        'issue_d', 'loan_status', 'purpose', 'earliest_cr_line',
#        'initial_list_status', 'application_type', 'address'],
#       dtype='object')

# %%
feat_info('term')
# Out:
# The number of payments on the loan. Values are in months and can be either 36 or 60.

# %%
df.term.value_counts()
# Out:
#  36 months    301247
#  60 months     93972
# Name: term, dtype: int64

# %%
df['term'] = df['term'].apply(lambda term: int(term[:3]))

# %%
df.term
# Out:
# 0         36
# 1         36
# 2         36
# 3         36
# 4         60
#           ..
# 396025    60
# 396026    36
# 396027    36
# 396028    60
# 396029    36
# Name: term, Length: 395219, dtype: int64

# %%
df = df.drop('grade',axis=1)

# %%
# https://www.youtube.com/watch?v=0s_1IsROgDc&t=619s refer to this video and 
dummies = pd.get_dummies(df.sub_grade, drop_first=True)

# %%
df = df.drop('sub_grade', axis=1)

# %%
df = pd.concat([df,dummies],axis=1)

# %%
dummies = pd.get_dummies(df[['verification_status', 'application_type','initial_list_status','purpose' ]],drop_first=True)
df = df.drop(['verification_status', 'application_type','initial_list_status','purpose'],axis=1)
df = pd.concat([df,dummies],axis=1)

# %%
df.home_ownership.value_counts()
# Out:
# MORTGAGE    198022
# RENT        159395
# OWN          37660
# OTHER          110
# NONE            29
# ANY              3
# Name: home_ownership, dtype: int64

# %%
# put NONE and ANY into the OTHER category
df['home_ownership'] = df.home_ownership.replace(['NONE','ANY'],'OTHER')

# %%
dummies = pd.get_dummies(df[['home_ownership']],drop_first=True)
df = df.drop(['home_ownership'],axis=1)
df = pd.concat([df,dummies],axis=1)

# %%
df.address
# Out:
# 0            0174 Michelle Gateway\r\nMendozaberg, OK 22690
# 1         1076 Carney Fort Apt. 347\r\nLoganmouth, SD 05113
# 2         87025 Mark Dale Apt. 269\r\nNew Sabrina, WV 05113
# 3                   823 Reid Ford\r\nDelacruzside, MA 00813
# 4                    679 Luna Roads\r\nGreggshire, VA 11650
#                                 ...
# 396025     12951 Williams Crossing\r\nJohnnyville, DC 30723
# 396026    0114 Fowler Field Suite 028\r\nRachelborough, ...
# 396027    953 Matthew Points Suite 414\r\nReedfort, NY 7...
# 396028    7843 Blake Freeway Apt. 229\r\nNew Michael, FL...
# 396029        787 Michelle Causeway\r\nBriannaton, AR 48052
# Name: address, Length: 395219, dtype: object

# %%
df['zip_code'] = df['address'].apply(lambda address:address[-5:])

# %%
dummies = pd.get_dummies(df['zip_code'],drop_first=True)
df = df.drop(['zip_code','address'],axis=1)
df = pd.concat([df,dummies],axis=1)

# %%
feat_info('issue_d')
# Out:
# The month which the loan was funded

# %%
  df = df.drop('issue_d',axis=1)

# %%
df['earliest_cr_year'] = df['earliest_cr_line'].apply(lambda date:int(date[-4:]))
df = df.drop('earliest_cr_line',axis=1)

# %%
df.earliest_cr_year
# Out:
# 0         1990
# 1         2004
# 2         2007
# 3         2006
# 4         1999
#           ...
# 396025    2004
# 396026    2006
# 396027    1997
# 396028    1990
# 396029    1998
# Name: earliest_cr_year, Length: 395219, dtype: int64

# %%
df.head(1)
# Out:
#    loan_amnt  term  int_rate  ...  86630  93700 earliest_cr_year
# 0    10000.0    36     11.44  ...      0      0             1990
#
# [1 rows x 80 columns]

# %%
df = df.drop('loan_status',axis=1)

# %%
X = df.drop('loan_repaid',axis=1).values

# %%
y = df.loan_repaid.values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (316175, 78)

# %%
model = Sequential()

model.add(Dense(78, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(39, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(19, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(units=1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam')

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
model.fit(x=X_train,y=y_train,epochs=25, batch_size=256,validation_data=(X_test,y_test))
# Out:
# Epoch 1/25
# 1236/1236 [==============================] - 3s 2ms/step - loss: 0.2988 - val_loss: 0.2640
# Epoch 2/25
# 1236/1236 [==============================] - 3s 2ms/step - loss: 0.2651 - val_loss: 0.2638
# Epoch 3/25
# 1236/1236 [==============================] - 3s 2ms/step - loss: 0.2626 - val_loss: 0.2625
# Epoch 4/25
# 1236/1236 [==============================] - 3s 2ms/step - loss: 0.2615 - val_loss: 0.2620
# Epoch 5/25
# 1236/1236 [==============================] - 3s 2ms/step - loss: 0.2608 - val_loss: 0.2617
# Epoch 6/25
# 1236/1236 [==============================] - 3s 2ms/step - loss: 0.2603 - val_loss: 0.2617
# Epoch 7/25
# 1236/1236 [==============================] - 3s 2ms/step - loss: 0.2599 - val_loss: 0.2613
# Epoch 8/25
# 1236/1236 [==============================] - 3s 2ms/step - loss: 0.2594 - val_loss: 0.2615
# Epoch 9/25
# 1236/1236 [==============================] - 3s 2ms/step - loss: 0.2591 - val_loss: 0.2615
# Epoch 10/25
# ...

# %%
losses = pd.DataFrame(model.history.history)
losses.plot()

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
predictions = model.predict_classes(X_test)
# Out:
# WARNING:tensorflow:From <ipython-input-258-bc83193b8b59>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.46      0.62     15658
#            1       0.88      0.99      0.93     63386
#
#     accuracy                           0.89     79044
#    macro avg       0.91      0.73      0.78     79044
# weighted avg       0.89      0.89      0.87     79044

# %%
import random
random.seed(101)
random_ind = random.randint(0,len(df))

new_customer = df.drop('loan_repaid',axis=1).iloc[random_ind]
new_customer
# Out:
# loan_amnt           25000.00
# term                   60.00
# int_rate               18.24
# installment           638.11
# annual_inc          61665.00
#                       ...
# 48052                   0.00
# 70466                   0.00
# 86630                   0.00
# 93700                   0.00
# earliest_cr_year     1996.00
# Name: 305323, Length: 78, dtype: float64

# %%
new_customer = scaler.transform(new_customer.values.reshape(1,78))

# %%
model.predict_classes(new_customer)
# Out:
# array([[1]], dtype=int32)
